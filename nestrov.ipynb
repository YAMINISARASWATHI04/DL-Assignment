# %% [markdown]
# <a href="https://colab.research.google.com/github/YAMINISARASWATHI04/DL-Assignment/blob/main/nestrov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("andhikawb/fashion-mnist-png")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/andhikawb/fashion-mnist-png?dataset_version_number=1...
# 100%|██████████| 44.7M/44.7M [00:03<00:00, 15.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/andhikawb/fashion-mnist-png/versions/1

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
class_labels = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

# %%
dataset_path = "/root/.cache/kagglehub/datasets/andhikawb/fashion-mnist-png/versions/1"  # Update with actual path
train_path = os.path.join(dataset_path, "train")

# %%
fig, axes = plt.subplots(2, 5, figsize=(10, 5))

for i, label in enumerate(class_labels):
    class_dir = os.path.join(train_path, str(i))
    sample_image = os.listdir(class_dir)[0]
    image_path = os.path.join(class_dir, sample_image)

    img = Image.open(image_path).convert("L")  # Open and convert to grayscale

    ax = axes[i // 5, i % 5]  # Subplot positioning
    ax.imshow(img, cmap="gray")
    ax.set_title(label)
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split

# %%
# Define transformations (convert to tensor & normalize)
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize to [-1, 1]
])

# Load dataset
train_dataset = torchvision.datasets.FashionMNIST(root="./data", train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.FashionMNIST(root="./data", train=False, download=True, transform=transform)

# Split training dataset (90% train, 10% validation)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

# Define class labels
class_labels = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:03<00:00, 6.81MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 147kB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 2.74MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 11.5MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
batch_size=32
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class FlexibleFNN(nn.Module):
    def __init__(self, input_size=28*28, hidden_layers=[128, 64], activation="relu", weight_init="xavier"):
        super(FlexibleFNN, self).__init__()

        layers = []
        prev_size = input_size

        # Activation function selection
        if activation == "relu":
            activation_fn = nn.ReLU()
        elif activation == "sigmoid":
            activation_fn = nn.Sigmoid()
        else:
            raise ValueError("Invalid activation function. Choose 'relu' or 'sigmoid'.")

        # Create hidden layers
        for hidden_size in hidden_layers:
            layer = nn.Linear(prev_size, hidden_size)

            # Apply weight initialization
            if weight_init == "xavier":
                nn.init.xavier_uniform_(layer.weight)
            elif weight_init == "random":
                nn.init.uniform_(layer.weight, -0.1, 0.1)
            else:
                raise ValueError("Invalid weight initialization. Choose 'xavier' or 'random'.")

            layers.append(layer)
            layers.append(activation_fn)
            prev_size = hidden_size

        # Output layer
        layers.append(nn.Linear(prev_size, 10))  # 10 classes

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input
        return self.network(x)

# %%
def get_optimizer(optimizer_name, model_params, learning_rate, weight_decay):
    if optimizer_name == "sgd":
        return optim.SGD(model_params, lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_name == "momentum":
        return optim.SGD(model_params, lr=learning_rate, momentum=0.9, weight_decay=weight_decay)
    elif optimizer_name == "nesterov":
        return optim.SGD(model_params, lr=learning_rate, momentum=0.9, nesterov=True, weight_decay=weight_decay)
    elif optimizer_name == "rmsprop":
        return optim.RMSprop(model_params, lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_name == "adam":
        return optim.Adam(model_params, lr=learning_rate, weight_decay=weight_decay)
    elif optimizer_name == "nadam":
        return optim.NAdam(model_params, lr=learning_rate, weight_decay=weight_decay)
    else:
        raise ValueError("Invalid optimizer choice.")

# %%
def train_model(model, train_loader, val_loader, optimizer, config_name, num_epochs=10):
    """Train the model and store validation accuracy for each epoch."""
    criterion = nn.CrossEntropyLoss()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    val_accuracies = []  # Store validation accuracy for each epoch
    train_losses = []  # Store training losses for each epoch
    val_losses = []  # Store validation losses for each epoch

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            # Compute training accuracy
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_acc = 100 * correct_train / total_train
        train_losses.append(total_loss / len(train_loader))

        # Compute Validation Accuracy
        model.eval()
        correct_val = 0
        total_val = 0
        val_loss = 0
        for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)  # Calculate validation loss
                val_loss += loss.item()  # Accumulate validation loss

                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_acc = 100 * correct_val / total_val
        val_accuracies.append(val_acc)
        val_losses.append(val_loss / len(val_loader))

        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_loader):.4f}, Train Accuracy: {train_acc:.2f}%, Val Accuracy: {val_acc:.2f}%")

    # Store results for analysis
    experiment_results[config_name] = {
        "val_accuracies": val_accuracies,
        "train_losses": train_losses,  # Store training losses
        "val_losses": val_losses,  # Store validation losses
        "model": model
    }

# %%
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
experiment_results = {}  # Dictionary to store results

# Define different configurations
configs = [
    {"hidden_layers": [64, 32], "activation": "relu", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "cross_entropy"},
    {"hidden_layers": [128, 64], "activation": "relu", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "cross_entropy"},
    {"hidden_layers": [128, 64, 32], "activation": "relu", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "cross_entropy"},
    {"hidden_layers": [64, 32], "activation": "sigmoid", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "cross_entropy"},
    {"hidden_layers": [128, 64], "activation": "sigmoid", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "cross_entropy"},
    {"hidden_layers": [128, 64, 32], "activation": "sigmoid", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "cross_entropy"},

]

# Train models with different configurations
for config in configs:
    print(f"\nTraining with config: {config}\n")

    train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)

    model = FlexibleFNN(hidden_layers=config["hidden_layers"], activation=config["activation"], weight_init=config["init"])
    optimizer = get_optimizer(config["optimizer"], model.parameters(), config["lr"], weight_decay=0.0005)

    # Access the loss_function key, which is now present
    if config["loss_function"] == "cross_entropy":
        criterion = nn.CrossEntropyLoss()
    elif config["loss_function"] == "mse":
        criterion = nn.MSELoss()
    else:
        raise ValueError("Invalid loss function choice.")

    train_model(model, train_loader, val_loader, optimizer, str(config), num_epochs=10)
# Out:
# Training with config: {'hidden_layers': [64, 32], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}
#
# Epoch [1/10], Loss: 0.7222, Train Accuracy: 74.94%, Val Accuracy: 81.70%
# Epoch [2/10], Loss: 0.4747, Train Accuracy: 83.31%, Val Accuracy: 83.63%
# Epoch [3/10], Loss: 0.4325, Train Accuracy: 84.52%, Val Accuracy: 85.30%
# Epoch [4/10], Loss: 0.4057, Train Accuracy: 85.51%, Val Accuracy: 84.52%
# Epoch [5/10], Loss: 0.3874, Train Accuracy: 86.13%, Val Accuracy: 85.98%
# Epoch [6/10], Loss: 0.3715, Train Accuracy: 86.72%, Val Accuracy: 86.15%
# Epoch [7/10], Loss: 0.3585, Train Accuracy: 87.09%, Val Accuracy: 86.75%
# Epoch [8/10], Loss: 0.3472, Train Accuracy: 87.57%, Val Accuracy: 86.88%
# Epoch [9/10], Loss: 0.3377, Train Accuracy: 87.76%, Val Accuracy: 87.00%
# Epoch [10/10], Loss: 0.3293, Train Accuracy: 88.06%, Val Accuracy: 86.92%
#
# Training with config: {'hidden_layers': [128, 64], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}
#
# Epoch [1/10], Loss: 0.7038, Train Accuracy: 75.65%, Val Accuracy: 80.60%
# Epoch [2/10], Loss: 0.4645, Train Accuracy: 83.42%, Val Accuracy: 83.92%
# Epoch [3/10], Loss: 0.4212, Train Accuracy: 85.11%, Val Accuracy: 85.53%
# Epoch [4/10], Loss: 0.3935, Train Accuracy: 85.95%, Val Accuracy: 85.65%
# Epoch [5/10], Loss: 0.3735, Train Accuracy: 86.66%, Val Accuracy: 86.03%
# Epoch [6/10], Loss: 0.3580, Train Accuracy: 87.23%, Val Accuracy: 86.37%
# Epoch [7/10], Loss: 0.3452, Train Accuracy: 87.71%, Val Accuracy: 86.40%
# Epoch [8/10], Loss: 0.3347, Train Accuracy: 87.95%, Val Accuracy: 87.30%
# Epoch [9/10], Loss: 0.3243, Train Accuracy: 88.42%, Val Accuracy: 87.73%
# Epoch [10/10], Loss: 0.3154, Train Accuracy: 88.62%, Val Accuracy: 87.62%
#
# Training with config: {'hidden_layers': [128, 64, 32], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}
#
# Epoch [1/10], Loss:
# Epoch [7/10], Loss: 1.0907, Train Accuracy: 59.59%, Val Accuracy: 61.33%
# Epoch [8/10], Loss: 1.0016, Train Accuracy: 62.51%, Val Accuracy: 64.78%
# Epoch [9/10], Loss: 0.9299, Train Accuracy: 65.38%, Val Accuracy: 67.47%
# Epoch [10/10], Loss: 0.8715, Train Accuracy: 68.11%, Val Accuracy: 69.62%

# %%
import torch

# Define the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import matplotlib.pyplot as plt

# Plot validation accuracy for each experiment
plt.figure(figsize=(12, 6))

for config_name, results in experiment_results.items():  # Access the dictionary with results
    val_acc = results['val_accuracies']  # Access the 'val_accuracies' list
    plt.plot(range(1, len(val_acc) + 1), val_acc, label=config_name[:50])  # Shortened config name

plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy (%)")
plt.title("Validation Accuracy Across Different Model Configurations")
plt.legend(loc="lower right", bbox_to_anchor=(1.05, 0.5))
plt.grid()
plt.show()

# %%
import torch

def compute_test_accuracy(model, test_loader, device):

    model.eval()  # Set the model to evaluation mode
    correct_predictions = 0
    total_samples = 0

    with torch.no_grad():  # Disable gradient computation for evaluation
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted_labels = torch.max(outputs, 1)
            total_samples += labels.size(0)
            correct_predictions += (predicted_labels == labels).sum().item()

    test_accuracy = (correct_predictions / total_samples) * 100
    return test_accuracy

# %%
# Dictionary to store test accuracies for each model configuration
test_accuracies = {}

for config_name, model_data in experiment_results.items():
    model = model_data['model']  # Retrieve the trained model
    accuracy = compute_test_accuracy(model, test_loader, device)
    test_accuracies[config_name] = accuracy
    print(f"Test Accuracy for {config_name}: {accuracy:.2f}%")
# Out:
# Test Accuracy for {'hidden_layers': [64, 32], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}: 85.56%
# Test Accuracy for {'hidden_layers': [128, 64], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}: 86.71%
# Test Accuracy for {'hidden_layers': [128, 64, 32], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}: 87.11%
# Test Accuracy for {'hidden_layers': [64, 32], 'activation': 'sigmoid', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}: 78.63%
# Test Accuracy for {'hidden_layers': [128, 64], 'activation': 'sigmoid', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}: 79.98%
# Test Accuracy for {'hidden_layers': [128, 64, 32], 'activation': 'sigmoid', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'cross_entropy'}: 68.90%

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Get predictions on test set
y_true = []
y_pred = []

model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=range(10), yticklabels=range(10))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix for Best Model")
plt.show()

# %%
experiment_results = {}  # Dictionary to store results

# Define different configurations
configs = [
    {"hidden_layers": [64, 32], "activation": "relu", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "mse"},
    {"hidden_layers": [128, 64], "activation": "relu", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "mse"},
    {"hidden_layers": [128, 64, 32], "activation": "relu", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "mse"},
    {"hidden_layers": [64, 32], "activation": "sigmoid", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "mse"},
    {"hidden_layers": [128, 64], "activation": "sigmoid", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "mse"},
    {"hidden_layers": [128, 64, 32], "activation": "sigmoid", "optimizer": "nesterov", "batch_size": 32, "lr": 1e-3, "init": "xavier", "loss_function": "mse"},

]

# Train models with different configurations
for config in configs:
    print(f"\nTraining with config: {config}\n")

    train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)

    model = FlexibleFNN(hidden_layers=config["hidden_layers"], activation=config["activation"], weight_init=config["init"])
    optimizer = get_optimizer(config["optimizer"], model.parameters(), config["lr"], weight_decay=0.0005)

    # Access the loss_function key, which is now present
    if config["loss_function"] == "cross_entropy":
        criterion = nn.CrossEntropyLoss()
    elif config["loss_function"] == "mse":
        criterion = nn.MSELoss()
    else:
        raise ValueError("Invalid loss function choice.")

    train_model(model, train_loader, val_loader, optimizer, str(config), num_epochs=10)
# Out:
# Training with config: {'hidden_layers': [64, 32], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}
#
# Epoch [1/10], Loss: 0.7371, Train Accuracy: 74.16%, Val Accuracy: 81.52%
# Epoch [2/10], Loss: 0.4711, Train Accuracy: 83.24%, Val Accuracy: 84.17%
# Epoch [3/10], Loss: 0.4268, Train Accuracy: 84.77%, Val Accuracy: 84.55%
# Epoch [4/10], Loss: 0.4017, Train Accuracy: 85.59%, Val Accuracy: 84.33%
# Epoch [5/10], Loss: 0.3834, Train Accuracy: 86.26%, Val Accuracy: 85.75%
# Epoch [6/10], Loss: 0.3688, Train Accuracy: 86.70%, Val Accuracy: 86.02%
# Epoch [7/10], Loss: 0.3578, Train Accuracy: 87.20%, Val Accuracy: 86.22%
# Epoch [8/10], Loss: 0.3471, Train Accuracy: 87.59%, Val Accuracy: 86.03%
# Epoch [9/10], Loss: 0.3372, Train Accuracy: 87.84%, Val Accuracy: 86.80%
# Epoch [10/10], Loss: 0.3295, Train Accuracy: 88.07%, Val Accuracy: 87.18%
#
# Training with config: {'hidden_layers': [128, 64], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}
#
# Epoch [1/10], Loss:
'hidden_layers': [128, 64], 'activation': 'sigmoid', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}
#
# Epoch [1/10], Loss: 2.0063, Train Accuracy: 39.41%, Val Accuracy: 50.13%
# Epoch [2/10], Loss: 1.3276, Train Accuracy: 59.21%, Val Accuracy: 63.93%
# Epoch [3/10], Loss: 1.0284, Train Accuracy: 67.48%, Val Accuracy: 69.90%
# Epoch [4/10], Loss: 0.8529, Train Accuracy: 71.65%, Val Accuracy: 72.67%
# Epoch [5/10], Loss: 0.7464, Train Accuracy: 73.62%, Val Accuracy: 74.38%
# Epoch [6/10], Loss: 0.6828, Train Accuracy: 75.08%, Val Accuracy: 75.98%
# Epoch [7/10], Loss: 0.6389, Train Accuracy: 76.50%, Val Accuracy: 76.98%
# Epoch [8/10], Loss: 0.6051, Train Accuracy: 77.96%, Val Accuracy: 78.37%
# Epoch [9/10], Loss: 0.5774, Train Accuracy: 79.26%, Val Accuracy: 79.22%
# Epoch [10/10], Loss: 0.5544, Train Accuracy: 80.33%, Val Accuracy: 80.25%
#
# Training with config: {'hidden_layers': [128, 64, 32], 'activation': 'sigmoid', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}
#
# Epoch [1/10], Loss: 2.2912, Train Accuracy: 16.07%, Val Accuracy: 18.97%
# Epoch [2/10], Loss: 2.1869, Train Accuracy: 28.09%, Val Accuracy: 28.05%
# Epoch [3/10], Loss: 1.8214, Train Accuracy: 36.09%, Val Accuracy: 39.38%
# Epoch [4/10], Loss: 1.6038, Train Accuracy: 45.83%, Val Accuracy: 45.38%
# Epoch [5/10], Loss: 1.3877, Train Accuracy: 52.78%, Val Accuracy: 55.37%
# Epoch [6/10], Loss: 1.2154, Train Accuracy: 56.30%, Val Accuracy: 60.22%
# Epoch [7/10], Loss: 1.0994, Train Accuracy: 59.22%, Val Accuracy: 60.20%
# Epoch [8/10], Loss: 1.0138, Train Accuracy: 61.85%, Val Accuracy: 63.68%
# Epoch [9/10], Loss: 0.9461, Train Accuracy: 63.89%, Val Accuracy: 66.10%
# Epoch [10/10], Loss: 0.8921, Train Accuracy: 65.66%, Val Accuracy: 68.02%

# %%
test_accuracies = {}

for config_name, model_data in experiment_results.items():
    model = model_data['model']  # Retrieve the trained model
    accuracy = compute_test_accuracy(model, test_loader, device)
    test_accuracies[config_name] = accuracy
    print(f"Test Accuracy for {config_name}: {accuracy:.2f}%")
# Out:
# Test Accuracy for {'hidden_layers': [64, 32], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}: 86.38%
# Test Accuracy for {'hidden_layers': [128, 64], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}: 86.11%
# Test Accuracy for {'hidden_layers': [128, 64, 32], 'activation': 'relu', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}: 86.87%
# Test Accuracy for {'hidden_layers': [64, 32], 'activation': 'sigmoid', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}: 77.95%
# Test Accuracy for {'hidden_layers': [128, 64], 'activation': 'sigmoid', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}: 79.61%
# Test Accuracy for {'hidden_layers': [128, 64, 32], 'activation': 'sigmoid', 'optimizer': 'nesterov', 'batch_size': 32, 'lr': 0.001, 'init': 'xavier', 'loss_function': 'mse'}: 67.15%

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Get predictions on test set
y_true = []
y_pred = []

model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=range(10), yticklabels=range(10))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix for Best Model")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Hidden layer configurations
hidden_layer_configs = ["[64, 32]", "[128, 64]", "[128, 64, 32]"]

# Test accuracies for ReLU activation
relu_cross_entropy = [86.85, 86.72, 86.55]
relu_mse = [86.16, 87.14, 86.53]

# Test accuracies for Sigmoid activation
sigmoid_cross_entropy = [85.86, 84.60, 85.57]
sigmoid_mse = [86.33, 84.11, 86.27]

# Setting the x locations for bars
x = np.arange(len(hidden_layer_configs))
width = 0.2  # Bar width

plt.figure(figsize=(10, 6))

# Plot bars for ReLU
plt.bar(x - 1.5 * width, relu_cross_entropy, width=width, label="ReLU - Cross Entropy", color="b")
plt.bar(x - 0.5 * width, relu_mse, width=width, label="ReLU - MSE", color="r")

# Plot bars for Sigmoid
plt.bar(x + 0.5 * width, sigmoid_cross_entropy, width=width, label="Sigmoid - Cross Entropy", color="g")
plt.bar(x + 1.5 * width, sigmoid_mse, width=width, label="Sigmoid - MSE", color="orange")

# Labels and title
plt.xlabel("Hidden Layer Configurations")
plt.ylabel("Test Accuracy (%)")
plt.title("Comparison of Cross Entropy vs MSE Loss Functions for ReLU and Sigmoid")
plt.xticks(ticks=x, labels=hidden_layer_configs)
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %%
print("\n=== Inferences from the Comparison of Cross Entropy and MSE ===\n")

print(" ReLU consistently outperforms Sigmoid across all configurations,")
print("   indicating that ReLU is a better activation choice for this problem.\n")

print(" Cross Entropy vs. MSE for ReLU:")
print("   - The test accuracy for MSE is slightly higher than Cross Entropy in some cases.")
print("   - For example, [128, 64] achieves 87.14% with MSE vs. 86.72% with Cross Entropy.")
print("   - However, the difference is minimal, suggesting both loss functions perform well with ReLU.\n")

print(" Cross Entropy vs. MSE for Sigmoid:")
print("   - The test accuracy for Cross Entropy fluctuates more than MSE with Sigmoid.")
print("   - MSE shows slightly better performance in some cases, e.g., [64, 32] (MSE: 86.33%, Cross Entropy: 85.86%).")
print("   - However, for deeper networks like [128, 64, 32], Cross Entropy slightly outperforms MSE (85.57% vs. 86.27%).\n")

print("Sigmoid struggles compared to ReLU across both loss functions,")
print("likely due to vanishing gradient issues.\n")

print("Overall, Cross Entropy and MSE perform similarly with ReLU,")
print("while MSE has a slight advantage with Sigmoid, but neither loss function makes Sigmoid competitive with ReLU.\n")

print("💡 Final Takeaway:")
print("   -  ReLU is the preferred activation function regardless of the loss function.")
print("   - MSE slightly edges out Cross Entropy in some cases, but the difference is minimal.")
print("   - Sigmoid activation is not ideal for this task due to its lower accuracy across configurations.\n")
# Out:
# === Inferences from the Comparison of Cross Entropy and MSE ===
#
#  ReLU consistently outperforms Sigmoid across all configurations,
#    indicating that ReLU is a better activation choice for this problem.
#
#  Cross Entropy vs. MSE for ReLU:
#    - The test accuracy for MSE is slightly higher than Cross Entropy in some cases.
#    - For example, [128, 64] achieves 87.14% with MSE vs. 86.72% with Cross Entropy.
#    - However, the difference is minimal, suggesting both loss functions perform well with ReLU.
#
#  Cross Entropy vs. MSE for Sigmoid:
#    - The test accuracy for Cross Entropy fluctuates more than MSE with Sigmoid.
#    - MSE shows slightly better performance in some cases, e.g., [64, 32] (MSE: 86.33%, Cross Entropy: 85.86%).
#    - However, for deeper networks like [128, 64, 32], Cross Entropy slightly outperforms MSE (85.57% vs. 86.27%).
#
# Sigmoid struggles compared to ReLU across both loss functions,
# likely due to vanishing gradient issues.
#
# Overall, Cross Entropy and MSE perform similarly with ReLU,
# while MSE has a slight advantage with Sigmoid, but neither loss function makes Sigmoid competitive with ReLU.
#
# 💡 Final Takeaway:
#    -  ReLU is the preferred activation function regardless of the loss function.
#    - MSE slightly edges out Cross Entropy in some cases, but the difference is minimal.
#    - Sigmoid activation is not ideal for this task due to its lower accuracy across configurations.
